# %% [markdown]
# # Covid 19 data analysis

# %%
#importing the modules
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.rcParams['figure.figsize'] = [10, 6]

# %% [markdown]
# ### Task 2.1 - Importing the dataset

# %%
corona_dataset_csv = pd.read_csv('covid_19_confirmed_cases.csv')
corona_dataset_csv.head(10)
# Out:
#                  Province/State       Country/Region       Lat        Long  \
# 0                           NaN          Afghanistan  33.93911   67.709953
# 1                           NaN              Albania  41.15330   20.168300
# 2                           NaN              Algeria  28.03390    1.659600
# 3                           NaN              Andorra  42.50630    1.521800
# 4                           NaN               Angola -11.20270   17.873900
# 5                           NaN  Antigua and Barbuda  17.06080  -61.796400
# 6                           NaN            Argentina -38.41610  -63.616700
# 7                           NaN              Armenia  40.06910   45.038200
# 8  Australian Capital Territory            Australia -35.47350  149.012400
# 9               New South Wales            Australia -33.86880  151.209300
#
#    1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  12/31/20  \
# ...

# %%
corona_dataset_csv
# Out:
#     Province/State      Country/Region        Lat        Long  1/22/20  \
# 0              NaN         Afghanistan  33.939110   67.709953        0
# 1              NaN             Albania  41.153300   20.168300        0
# 2              NaN             Algeria  28.033900    1.659600        0
# 3              NaN             Andorra  42.506300    1.521800        0
# 4              NaN              Angola -11.202700   17.873900        0
# ..             ...                 ...        ...         ...      ...
# 267            NaN             Vietnam  14.058324  108.277199        0
# 268            NaN  West Bank and Gaza  31.952200   35.233200        0
# 269            NaN               Yemen  15.552727   48.516388        0
# 270            NaN              Zambia -13.133897   27.849332        0
# 271            NaN            Zimbabwe -19.015438   29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  12/31/20  1/1/21  \
# ...

# %% [markdown]
# ### Task 2.2: Delete the useless columns

# %%
corona_dataset_csv.drop(['Lat','Long'],axis=1,inplace=True)

# %%
corona_dataset_csv.head(10)
# Out:
#                  Province/State       Country/Region  1/22/20  1/23/20  \
# 0                           NaN          Afghanistan        0        0
# 1                           NaN              Albania        0        0
# 2                           NaN              Algeria        0        0
# 3                           NaN              Andorra        0        0
# 4                           NaN               Angola        0        0
# 5                           NaN  Antigua and Barbuda        0        0
# 6                           NaN            Argentina        0        0
# 7                           NaN              Armenia        0        0
# 8  Australian Capital Territory            Australia        0        0
# 9               New South Wales            Australia        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  1/29/20  ...  12/31/20  \
# 0        0        0        0        0        0        0  ...     51526
# ...

# %% [markdown]
# ### Task 2.3: Aggregating the rows by the country

# %%
corona_dataset_agg = corona_dataset_csv.groupby("Country/Region").sum()
corona_dataset_agg.head(10)
# Out:
#                      1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan                0        0        0        0        0        0
# Albania                    0        0        0        0        0        0
# Algeria                    0        0        0        0        0        0
# Andorra                    0        0        0        0        0        0
# Angola                     0        0        0        0        0        0
# Antigua and Barbuda        0        0        0        0        0        0
# Argentina                  0        0        0        0        0        0
# Armenia                    0        0        0        0        0        0
# Australia                  0        0        0        0        4        5
# Austria                    0        0        0        0        0        0
#
#                      1/28/20  1/29/20  1/30/20  1/31/20  ...  12/31/20  \
# Country/Region                                           ...
# ...

# %% [markdown]
# ###  Task 2.4: Visualizing data related to a country

# %%
corona_dataset_agg.loc['China'].plot()
corona_dataset_agg.loc['Italy'].plot()
corona_dataset_agg.loc['Spain'].plot()
corona_dataset_agg.loc['India'].plot()
plt.legend()

# %%
#finding the total number of cases in India for January 5

corona_dataset_agg.loc['India']['1/5/21']
# Out:
# 10374932

# %%
# finding the countries which has total corona cases greater than 1 crore on 4 January 2021
df = corona_dataset_agg[corona_dataset_agg['1/5/21']>10000000]

# %%
df
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# India                 0        0        0        0        0        0        0
# US                    1        1        2        2        5        5        5
#
#                 1/29/20  1/30/20  1/31/20  ...  12/31/20    1/1/21    1/2/21  \
# Country/Region                             ...
# India                 0        1        1  ...  10266674  10286709  10323965
# US                    6        6        8  ...  19974564  20132054  20433912
#
#                   1/3/21    1/4/21    1/5/21    1/6/21    1/7/21    1/8/21  \
# Country/Region
# India           10340469  10356844  10374932  10395278  10413417  10413417
# US              20643229  20819087  21049605  21299340  21579569  21862773
#
#                   1/9/21
# Country/Region
# India           10450284
# US              22132396
#
# [2 rows x 354 columns]

# %% [markdown]
# ### task 3.1: caculating the first derivative of the curve of India

# %%
corona_dataset_agg.loc['India'].plot()
# Out:
# <AxesSubplot:>

# %%
corona_dataset_agg.loc['India'].diff().plot()
# Out:
# <AxesSubplot:>

# %%
corona_dataset_agg.loc['India'].diff()
# Out:
# 1/22/20        NaN
# 1/23/20        0.0
# 1/24/20        0.0
# 1/25/20        0.0
# 1/26/20        0.0
#             ...
# 1/5/21     18088.0
# 1/6/21     20346.0
# 1/7/21     18139.0
# 1/8/21         0.0
# 1/9/21     36867.0
# Name: India, Length: 354, dtype: float64

# %% [markdown]
# ### task 3.2: find maxmimum infection rate for India

# %%
corona_dataset_agg.loc['India'].diff().max()
# Out:
# 97894.0

# %%
corona_dataset_agg.loc['China'].diff().max()
# Out:
# 15136.0

# %%
corona_dataset_agg.loc['Italy'].diff().max()
# Out:
# 40902.0

# %%
corona_dataset_agg.loc['Spain'].diff().max()
# Out:
# 55019.0

# %%
corona_dataset_agg.loc['US'].diff().max()
# Out:
# 301858.0

# %% [markdown]
# ### Task 3.3: find maximum infection rate for all of the countries.

# %%
countries = list(corona_dataset_agg.index)
max_infection_rates = []
for country in countries :
    max_infection_rates.append(corona_dataset_agg.loc[country].diff().max())
corona_dataset_agg['max infection rate'] = max_infection_rates

# %%
corona_dataset_agg.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  1/1/21  1/2/21  1/3/21  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...   51526   51526   51526
# Albania               0        0        0  ...   58316   58991   59438
# Algeria               0        0        0  ...   99897  100159  100408
# Andorra               0        0        0  ...    8117    8166    8192
# Angola                0        0        0  ...   17568   17608   17642
#
# ...

# %%
corona_dataset_agg.loc['India']
# Out:
# 1/22/20                      0.0
# 1/23/20                      0.0
# 1/24/20                      0.0
# 1/25/20                      0.0
# 1/26/20                      0.0
#                          ...
# 1/6/21                10395278.0
# 1/7/21                10413417.0
# 1/8/21                10413417.0
# 1/9/21                10450284.0
# max infection rate       97894.0
# Name: India, Length: 355, dtype: float64

# %%
# find the country with maximum max infection rate
corona_dataset_agg[corona_dataset_agg['max infection rate'] ==corona_dataset_agg['max infection rate'].max()]
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Turkey                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...   1/1/21   1/2/21   1/3/21  \
# Country/Region                             ...
# Turkey                0        0        0  ...  2220855  2232035  2241912
#
#                  1/4/21   1/5/21   1/6/21   1/7/21   1/8/21   1/9/21  \
# Country/Region
# Turkey          2255607  2270101  2283931  2296102  2307581  2317118
#
#                 max infection rate
# Country/Region
# Turkey                    823225.0
#
# [1 rows x 355 columns]

# %%
corona_dataset_agg[corona_dataset_agg['max infection rate'] ==corona_dataset_agg['max infection rate'].max()].index[0]
# Out:
# 'Turkey'

# %% [markdown]
# ### Task4:
# - Importing the WorldHappinessReport.csv dataset
# - Selecting needed columns for our analysis
# - Join the datasets
# - Calculate the correlations as the result of our analysis

# %% [markdown]
# ### Task 4.1 : importing the dataset

# %%
world_happiness_report = pd.read_csv("2020.csv")
world_happiness_report.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe        7.8087
# 1      Denmark     Western Europe        7.6456
# 2  Switzerland     Western Europe        7.5599
# 3      Iceland     Western Europe        7.5045
# 4       Norway     Western Europe        7.4880
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                        0.031156      7.869766      7.747634
# 1                        0.033492      7.711245      7.579955
# 2                        0.035014      7.628528      7.491272
# 3                        0.059616      7.621347      7.387653
# 4                        0.034837      7.556281      7.419719
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0              10.639267        0.954330                71.900825
# 1              10.774001        0.955991                72.402504
# 2              10.979933        0.942847                74.102448
# ...

# %%
world_happiness_report.shape
# Out:
# (153, 20)

# %% [markdown]
# ### Task 4.2: let's drop the useless columns

# %%
world_happiness_report = world_happiness_report.iloc[:,0:10]
world_happiness_report.shape
# Out:
# (153, 10)

# %%
world_happiness_report.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe        7.8087
# 1      Denmark     Western Europe        7.6456
# 2  Switzerland     Western Europe        7.5599
# 3      Iceland     Western Europe        7.5045
# 4       Norway     Western Europe        7.4880
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                        0.031156      7.869766      7.747634
# 1                        0.033492      7.711245      7.579955
# 2                        0.035014      7.628528      7.491272
# 3                        0.059616      7.621347      7.387653
# 4                        0.034837      7.556281      7.419719
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0              10.639267        0.954330                71.900825
# 1              10.774001        0.955991                72.402504
# 2              10.979933        0.942847                74.102448
# ...

# %%
columns_to_dropped = ['Regional indicator','Ladder score','Standard error of ladder score','upperwhisker','lowerwhisker']
world_happiness_report.drop(columns_to_dropped,axis=1 , inplace=True)

# %%
world_happiness_report.head()
# Out:
#   Country name  Logged GDP per capita  Social support  \
# 0      Finland              10.639267        0.954330
# 1      Denmark              10.774001        0.955991
# 2  Switzerland              10.979933        0.942847
# 3      Iceland              10.772559        0.974670
# 4       Norway              11.087804        0.952487
#
#    Healthy life expectancy  Freedom to make life choices
# 0                71.900825                      0.949172
# 1                72.402504                      0.951444
# 2                74.102448                      0.921337
# 3                73.000000                      0.948892
# 4                73.200783                      0.955750

# %%
world_happiness_report.set_index(['Country name'],inplace=True)

# %% [markdown]
# ### Task 4.4 Preparing the datasets and join them

# %%
corona_data = pd.DataFrame(corona_dataset_agg['max infection rate'])

# %%
corona_data.head()
# Out:
#                 max infection rate
# Country/Region
# Afghanistan                 1485.0
# Albania                      879.0
# Algeria                     1133.0
# Andorra                      299.0
# Angola                       355.0

# %%
world_happiness_report.head()
# Out:
#               Logged GDP per capita  Social support  Healthy life expectancy  \
# Country name
# Finland                   10.639267        0.954330                71.900825
# Denmark                   10.774001        0.955991                72.402504
# Switzerland               10.979933        0.942847                74.102448
# Iceland                   10.772559        0.974670                73.000000
# Norway                    11.087804        0.952487                73.200783
#
#               Freedom to make life choices
# Country name
# Finland                           0.949172
# Denmark                           0.951444
# Switzerland                       0.921337
# Iceland                           0.948892
# Norway                            0.955750

# %%
# Joining both the datasets

# %%
data = world_happiness_report.join(corona_data).copy()
data.head()
# Out:
#               Logged GDP per capita  Social support  Healthy life expectancy  \
# Country name
# Finland                   10.639267        0.954330                71.900825
# Denmark                   10.774001        0.955991                72.402504
# Switzerland               10.979933        0.942847                74.102448
# Iceland                   10.772559        0.974670                73.000000
# Norway                    11.087804        0.952487                73.200783
#
#               Freedom to make life choices  max infection rate
# Country name
# Finland                           0.949172               840.0
# Denmark                           0.951444              4508.0
# Switzerland                       0.921337             21926.0
# Iceland                           0.948892               106.0
# Norway                            0.955750              1680.0

# %% [markdown]
# ### Task 4.5: correlation matrix

# %%
data.corr()
# it is representing the currelation between every two columns of our dataset...
# Out:
#                               Logged GDP per capita  Social support  \
# Logged GDP per capita                      1.000000        0.781814
# Social support                             0.781814        1.000000
# Healthy life expectancy                    0.848469        0.742744
# Freedom to make life choices               0.419019        0.478863
# max infection rate                         0.126905        0.059843
#
#                               Healthy life expectancy  \
# Logged GDP per capita                        0.848469
# Social support                               0.742744
# Healthy life expectancy                      1.000000
# Freedom to make life choices                 0.448846
# max infection rate                           0.097849
#
#                               Freedom to make life choices  max infection rate
# Logged GDP per capita                             0.419019            0.126905
# ...

# %% [markdown]
# ### Task 5: Visualization of the results

# %%
data.head()
# Out:
#               Logged GDP per capita  Social support  Healthy life expectancy  \
# Country name
# Finland                   10.639267        0.954330                71.900825
# Denmark                   10.774001        0.955991                72.402504
# Switzerland               10.979933        0.942847                74.102448
# Iceland                   10.772559        0.974670                73.000000
# Norway                    11.087804        0.952487                73.200783
#
#               Freedom to make life choices  max infection rate
# Country name
# Finland                           0.949172               840.0
# Denmark                           0.951444              4508.0
# Switzerland                       0.921337             21926.0
# Iceland                           0.948892               106.0
# Norway                            0.955750              1680.0

# %% [markdown]
# ### Task 5.1:  GDP vs maximum Infection rate plot

# %%
x = data['Logged GDP per capita']
y = data['max infection rate']
sns.scatterplot(x,np.log(y))
# Out:
# C:\Users\shreyash\Anaconda\envs\Tensorr\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Logged GDP per capita', ylabel='max infection rate'>

# %%
sns.regplot(x,np.log(y))
# Out:
# C:\Users\shreyash\Anaconda\envs\Tensorr\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\shreyash\Anaconda\envs\Tensorr\lib\site-packages\numpy\linalg\linalg.py:1965: RuntimeWarning: invalid value encountered in greater
#   large = s > cutoff
# <AxesSubplot:xlabel='Logged GDP per capita', ylabel='max infection rate'>

# %% [markdown]
# ### Task 5.2: Plotting Social support vs maximum Infection rate

# %%
x = data['Social support']
y = data['max infection rate']
sns.scatterplot(x,np.log(y))
# Out:
# C:\Users\shreyash\Anaconda\envs\Tensorr\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Social support', ylabel='max infection rate'>

# %%
sns.regplot(x,np.log(y))
# Out:
# C:\Users\shreyash\Anaconda\envs\Tensorr\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Social support', ylabel='max infection rate'>

# %% [markdown]
# ### Task 5.3: Plotting Healthy life expectancy vs maximum Infection rate

# %%
x = data['Healthy life expectancy']
y = data['max infection rate']
sns.scatterplot(x,np.log(y))
# Out:
# C:\Users\shreyash\Anaconda\envs\Tensorr\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Healthy life expectancy', ylabel='max infection rate'>

# %%
sns.regplot(x,np.log(y))
# Out:
# C:\Users\shreyash\Anaconda\envs\Tensorr\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Healthy life expectancy', ylabel='max infection rate'>

# %% [markdown]
# ### Task 5.4: Plotting Freedom to make life choices vs maximum Infection rate

# %%
x = data['Freedom to make life choices']
y = data['max infection rate']
sns.scatterplot(x,np.log(y))
# Out:
# C:\Users\shreyash\Anaconda\envs\Tensorr\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Freedom to make life choices', ylabel='max infection rate'>

# %%
sns.regplot(x,np.log(y))
# Out:
# C:\Users\shreyash\Anaconda\envs\Tensorr\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Freedom to make life choices', ylabel='max infection rate'>
